# %%
import numpy as np # n-dim
import skimage #scikit-image
import matplotlib.pyplot as plt # mostrar imágenes

# %%
im = skimage.data.coins()

# %%
im
# Out:
# array([[ 47, 123, 133, ...,  14,   3,  12],
#        [ 93, 144, 145, ...,  12,   7,   7],
#        [126, 147, 143, ...,   2,  13,   3],
#        ...,
#        [ 81,  79,  74, ...,   6,   4,   7],
#        [ 88,  82,  74, ...,   5,   7,   8],
#        [ 91,  79,  68, ...,   4,  10,   7]], dtype=uint8)

# %%
im.shape #escala de grises
# Out:
# (303, 384)

# %%
303*384
# Out:
# 116352

# %%
im = skimage.data.coins()
plt.imshow(im, cmap='gray')

# %%
#@title Cambiar valor de t { run: "auto" }
t = 136 #@param {type:"slider", min:0, max:255, step:1}
im_th = im.copy()
im_th[im_th<t] = 0
im_th[im_th>=t] = 255
plt.figure()
plt.imshow(im_th, cmap='gray')

#Binarizar la imagen

# %%
im.ravel()
#nivel 0 -> 47
#...
#nivel 255 -> 7
# Out:
# array([ 47, 123, 133, ...,   4,  10,   7], dtype=uint8)

# %%
r = im.ravel()

# %%
r
# Out:
# array([ 47, 123, 133, ...,   4,  10,   7], dtype=uint8)

# %%
r.shape
# Out:
# (116352,)

# %%
plt.hist(r, bins=255);
