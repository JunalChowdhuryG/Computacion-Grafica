# %%
import numpy as np
import skimage #scikit-image
from skimage.io import imread
import matplotlib.pyplot as plt

# %% [markdown]
# ### Lectura de la imagen

# %%
# !wget http://www.guidetofilmphotography.com/photos/bw-negative.jpg
# Out:
# --2025-08-30 16:39:45--  http://www.guidetofilmphotography.com/photos/bw-negative.jpg
# Resolving www.guidetofilmphotography.com (www.guidetofilmphotography.com)... 50.87.149.192
# Connecting to www.guidetofilmphotography.com (www.guidetofilmphotography.com)|50.87.149.192|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 102246 (100K) [image/jpeg]
# Saving to: ‘bw-negative.jpg’
#
# bw-negative.jpg     100%[===================>]  99.85K  --.-KB/s    in 0.07s
#
# 2025-08-30 16:39:45 (1.43 MB/s) - ‘bw-negative.jpg’ saved [102246/102246]

# %%
# !wget https://makerworld.bblmw.com/makerworld/model/DSM00000001450106/design/2025-05-24_bd34548c0e23e8.png
# Out:
# --2025-08-30 16:39:45--  https://makerworld.bblmw.com/makerworld/model/DSM00000001450106/design/2025-05-24_bd34548c0e23e8.png
# Resolving makerworld.bblmw.com (makerworld.bblmw.com)... 172.64.144.14, 104.18.43.242, 2606:4700:4400::6812:2bf2, ...
# Connecting to makerworld.bblmw.com (makerworld.bblmw.com)|172.64.144.14|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 204308 (200K) [application/octet-stream]
# Saving to: ‘2025-05-24_bd34548c0e23e8.png’
#
# 2025-05-24_bd34548c 100%[===================>] 199.52K  --.-KB/s    in 0.03s
#
# 2025-08-30 16:39:45 (5.91 MB/s) - ‘2025-05-24_bd34548c0e23e8.png’ saved [204308/204308]

# %%
url = '2025-05-24_bd34548c0e23e8.png'
im = imread(url)
im = im[::-1,::-1,0]
plt.imshow(im, cmap='gray')

# %%
url = 'bw-negative.jpg'
im = imread(url)
im = im[:,:500,0]
plt.imshow(im, cmap='gray')

# %% [markdown]
# ### Revelar la imagen

# %%
im
# Out:
# array([[194, 194, 194, ..., 246, 248, 254],
#        [182, 182, 182, ..., 247, 248, 254],
#        [184, 184, 185, ..., 247, 249, 254],
#        ...,
#        [115, 170, 208, ..., 202, 201, 205],
#        [112, 168, 207, ..., 202, 202, 207],
#        [104, 158, 202, ..., 202, 204, 211]], dtype=uint8)

# %%
print(im)
# Out:
# [[194 194 194 ... 246 248 254]
#  [182 182 182 ... 247 248 254]
#  [184 184 185 ... 247 249 254]
#  ...
#  [115 170 208 ... 202 201 205]
#  [112 168 207 ... 202 202 207]
#  [104 158 202 ... 202 204 211]]

# %%
print(-im)
# Out:
# [[ 62  62  62 ...  10   8   2]
#  [ 74  74  74 ...   9   8   2]
#  [ 72  72  71 ...   9   7   2]
#  ...
#  [141  86  48 ...  54  55  51]
#  [144  88  49 ...  54  54  49]
#  [152  98  54 ...  54  52  45]]

# %%
im.shape
# Out:
# (665, 500)

# %%
#modificar
im_revelado = 255 - im

# %%
print(im_revelado)
# Out:
# [[ 61  61  61 ...   9   7   1]
#  [ 73  73  73 ...   8   7   1]
#  [ 71  71  70 ...   8   6   1]
#  ...
#  [140  85  47 ...  53  54  50]
#  [143  87  48 ...  53  53  48]
#  [151  97  53 ...  53  51  44]]

# %%
im_revelado
# Out:
# array([[ 61,  61,  61, ...,   9,   7,   1],
#        [ 73,  73,  73, ...,   8,   7,   1],
#        [ 71,  71,  70, ...,   8,   6,   1],
#        ...,
#        [140,  85,  47, ...,  53,  54,  50],
#        [143,  87,  48, ...,  53,  53,  48],
#        [151,  97,  53, ...,  53,  51,  44]], dtype=uint8)

# %% [markdown]
# ### Mostrar imagen revelada

# %%
plt.imshow(im_revelado, cmap='gray')

# %%
#modificar

# %%
plt.imshow(im_revelado, cmap='gray')

# %%
im_revelado.shape
# Out:
# (665, 500)

# %%
im_revelado = im_revelado
plt.imshow(im_revelado, cmap='gray')
